# %%
import sys
from pathlib import Path

root = Path.cwd()
repo_root = str(root)

# %%
from src import Relation

# %%
relation = Relation()
constraint = (relation.a_before_b_count == 1)

# %%
constraint
# Out:
# Equal(left=ABeforeBCount(), right=Constant(value=1))

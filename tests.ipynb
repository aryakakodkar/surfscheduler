# %%
import sys
from pathlib import Path

root = Path.cwd()
repo_root = str(root)

# %%
from src import Relation
from src.compiler import evaluate_expression, collect_loop_values

# %%
relation = Relation()

expr = (relation.a_before_b_count == 1) & (relation.b_before_a_count == 2)

# %%
collect_loop_values(expr)
# Out:
# {'a_before_b_count', 'b_before_a_count'}
